# %% [markdown]
# <a href="https://colab.research.google.com/github/oshimansari/new-python/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python program to merge two lists

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
merged_list = list1 + list2
print("Merged list:", merged_list)
# Out:
# Merged list: [1, 2, 3, 4, 5, 6]
