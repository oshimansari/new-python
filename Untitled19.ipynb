# %% [markdown]
# <a href="https://colab.research.google.com/github/oshimansari/new-python/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python program to remove duplicates from a string

# %%
# Input string
text = input("Enter a string: ")
result = ""
for char in text:
    if char not in result:
         result += char
print("string after removing duplicates:",result)
# Out:
# Enter a string: engineering
# string after removing duplicates: engir
