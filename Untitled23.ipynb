# %% [markdown]
# <a href="https://colab.research.google.com/github/oshimansari/new-python/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python program to find second largest number

# %%
numbers = [12, 45, 67, 23, 89, 67]
# Remove duplicates and sort
unique_numbers = list(set(numbers))
unique_numbers.sort()
if len(unique_numbers) >= 2:
    print("Second largest number:", unique_numbers[-2])
else:
    print("There is no second largest number.")
# Out:
# Second largest number: 67
